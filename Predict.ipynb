# %%
import numpy as np
import pandas as pd 
import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('criminal_train.csv')
df1 = pd.read_csv('criminal_test.csv')
df1.head()
# Out:
#       PERID  IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  \
# 0  66583679        4         0         4         1         2         1
# 1  35494679        4         0         4         1         1         1
# 2  79424679        2         0         3         1         2         1
# 3  11744679        4         0         6         1         2         1
# 4  31554679        1         0         4         1         3         1
#
#    IRHH65_2  IIHH65_2  PRXRETRY  ...    POVERTY3  TOOLONG  TROUBUND  PDEN10  \
# 0         1         1        99  ...           2        2         2       1
# 1         1         1        99  ...           3        2         2       1
# 2         1         1        99  ...           1        2         2       2
# 3         1         1        99  ...           3        2         2       1
# 4         1         1        99  ...           3        2         1       1
#
#    COUTYP2  MAIIN102  AIIND102      ANALWT_C  VESTR  VEREP
# ...

# %%
df2 = df.drop('PERID',1)
X = df2.iloc[:,:-1]
y = df2.iloc[:,-1]
X.shape, y.shape

X1 = df1.iloc[:,1:]
X1.shape
# Out:
# (11430, 70)

# %%
X1
# Out:
#        IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  \
# 0            4         0         4         1         2         1         1
# 1            4         0         4         1         1         1         1
# 2            2         0         3         1         2         1         1
# 3            4         0         6         1         2         1         1
# 4            1         0         4         1         3         1         1
# 5            1         0         6         1         4         1         1
# 6            4         0         2         1         1         1         2
# 7            4         0         1         1         1         1         1
# 8            4         0         2         1         1         1         1
# 9            4         0         2         1         1         1         3
# 10           4         0         2         1         1         1         1
# ...

# %%
clf = RandomForestClassifier(n_estimators = 100, n_jobs=2, max_depth=20).fit(X,y)
"""from sklearn.model_selection import GridSearchCV
grid_vals = {'n_estimators': [50, 100, 200, 300, 400, 500], 'max_depth': [5,10,15,20,25,30,40]}
grid_clf = GridSearchCV(clf, param_grid=grid_vals, scoring='accuracy')
grid_clf.fit(X,y)
grid_clf.best_score_,grid_clf.best_params_"""
# Out:
# "from sklearn.model_selection import GridSearchCV\ngrid_vals = {'n_estimators': [50, 100, 200, 300, 400, 500], 'max_depth': [5,10,15,20,25,30,40]}\ngrid_clf = GridSearchCV(clf, param_grid=grid_vals, scoring='accuracy')\ngrid_clf.fit(X,y)\ngrid_clf.best_score_,grid_clf.best_params_"

# %%
pred = clf.predict(X1)

# %%
perid = df1.iloc[:,0]
perid
df = pd.DataFrame(data={'PERID':perid, 'Criminal':pred})

# %%
df = df[['PERID','Criminal']]

df
# Out:
#           PERID  Criminal
# 0      66583679         0
# 1      35494679         0
# 2      79424679         0
# 3      11744679         0
# 4      31554679         0
# 5      83164679         0
# 6      58474679         0
# 7      40695779         0
# 8      39315779         0
# 9      58415779         0
# 10     23535779         0
# 11     67275779         0
# 12     93485779         0
# 13     29546779         0
# 14     97556779         0
# 15     37797779         0
# 16     36607779         0
# 17     61727779         0
# 18     20827779         0
# 19     52437779         0
# 20     87267779         0
# 21     33287779         0
# 22     30398779         0
# 23     98598779         0
# 24     41818779         1
# 25     69638779         0
# 26     25748779         0
# 27     75368779         0
# 28     99968779         0
# 29     91578779         1
# ...         ...       ...
# 11400  43750730         1
# 11401  35360730         0
# 11402  51380730         0
# ...

# %%
df.to_csv('answer2.csv', index = False)
